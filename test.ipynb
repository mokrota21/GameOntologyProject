# %%
from bs4 import BeautifulSoup
import requests

# %%
def extract_info_fandom(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    infobox = soup.find(class_=lambda class_name: class_name and 'infobox' in class_name)
    return infobox

from bs4 import NavigableString, Tag

from bs4 import NavigableString, Tag

def extract_grouped_text(element):
    if isinstance(element, NavigableString):
        return element.strip()

    if not element.contents:
        return []

    grouped_text = []
    current_text = []

    for child in element.contents:
        if isinstance(child, NavigableString):
            text = child.strip()
            if text:
                current_text.append(text)
        elif isinstance(child, Tag):
            if child.name == 'br':
                pass
                # current_text.append(' ')  # Add space instead of creating a new entry
            else:
                if current_text:
                    grouped_text.append(' '.join(current_text))
                    current_text = []
                child_group = extract_grouped_text(child)
                if child_group:
                    grouped_text.append(child_group)

    if current_text:
        grouped_text.append(' '.join(current_text))

    if len(grouped_text) == 1:
        return grouped_text[0]
    return grouped_text

def strip_list(l):
    for i in range(len(l)):
        while len(l[i]) == 1 and isinstance(l[i], list):
            l[i] = l[i][0]
        if isinstance(l[i], list):
            l[i] = strip_list(l[i])
    return l

# Assume that first element is alway key (string)
# List may be of length 2 or more
# If length 2 than second item is value
# Otherwise we combine everything after 1st element as a list 
# In both cases recursively apply grouped_to_dict to all elements
def grouped_to_dict(clear_groups):
    # print(clear_groups)
    res = {}
    key = clear_groups[0]
    while not isinstance(key, str):
        key = key[0]
    if len(clear_groups) == 2 and isinstance(clear_groups[1], str):
        res[key] = clear_groups[1]
    elif len(clear_groups) == 2:
        res[key] = grouped_to_dict(clear_groups[1])
    elif len(clear_groups) > 2 and isinstance(clear_groups[1], str):
        res[key] = grouped_to_dict(clear_groups[1:])
    else:
        value = []
        for i in range(1, len(clear_groups)):
            value.append(grouped_to_dict(clear_groups[i]))
        # print(key)
        res[key] = value
    return res

# %%
def extract_infobox(page_url):
    data_dict = None
    infobox = extract_info_fandom(page_url)
    if infobox:
        grouped_text = extract_grouped_text(infobox)
        if grouped_text:
            clear_groups = strip_list(grouped_text)
            if clear_groups:
                data_dict = grouped_to_dict(clear_groups)
    return data_dict

# %%
extract_infobox('https://eldenring.fandom.com//wiki/%22Champion%27s_Song%22_Painting')
# Out:
# {'"Champion\'s Song" Painting': {'絵画「英雄の歌」': {'Basic Information': [{'Type': 'Info Item'},
#     {'Category': 'Painting'},
#     {'Max. Held': '1'},
#     {'Item Effect': 'Reminiscence of the painting "Champion\'s Song"'},
#     {'Online Trade': 'No'}]}}}

# %%
def extract_data_fandom(game_head, data_collector):
    head_url = game_head
    all_pages_tail = 'wiki/Special:AllPages'
    all_pages_url = head_url + all_pages_tail
    response = requests.get(all_pages_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    all_pages = soup.find('ul', {'class': 'mw-allpages-chunk'})
    pages = all_pages.find_all('li')
    pages_urls = []
    for page in pages:
        tail = page.find('a').get('href')
        url = head_url + tail
        pages_urls.append(url)
    
    for page_url in pages_urls:
        print(page_url)
        data = extract_infobox(page_url)
        if data:
            data_collector.append(data)

# %%
data_er = []
extract_data_fandom('https://eldenring.fandom.com/', data_er)
# Out:
# https://eldenring.fandom.com//wiki/Affinity/Lightning
# https://eldenring.fandom.com//wiki/Affinity/Magic
# https://eldenring.fandom.com//wiki/Affinity/Occult
# https://eldenring.fandom.com//wiki/Affinity/Poison
# https://eldenring.fandom.com//wiki/Affinity/Quality
# https://eldenring.fandom.com//wiki/Affinity/Sacred
# https://eldenring.fandom.com//wiki/Affinity/Standard
# https://eldenring.fandom.com//wiki/Age_of_Duskborn
# https://eldenring.fandom.com//wiki/Age_of_Fracture
# https://eldenring.fandom.com//wiki/Age_of_Order
# https://eldenring.fandom.com//wiki/Age_of_Stars
# https://eldenring.fandom.com//wiki/Age_of_duskborn
# https://eldenring.fandom.com//wiki/Age_of_fracture
# https://eldenring.fandom.com//wiki/Age_of_order
# https://eldenring.fandom.com//wiki/Age_of_stars
# https://eldenring.fandom.com//wiki/Age_of_the_Duskborn
# https://eldenring.fandom.com//wiki/Age_of_the_Erdtree
# https://eldenring.fandom.com//wiki/Age_of_the_Stars
# https://eldenring.fandom.com//wiki/Age_of_the_Stars_(Achievement/Trophy)
# https://eldenring.fandom.com//wiki/Age_of_the_Stars_(disambiguation)
# https://eldenring.fandom.com//wiki/Age_of_the_duskborn
# https://eldenring.fandom.com//wiki/Age_of_the_stars
# https://eldenring.fandom.com//wiki/Aged_One%27s_Exultation
# https://eldenring.fandom.com//wiki/Agheel%27s_Flame
# https://eldenring.fandom.com//wiki/Ailing_Village
# https://eldenring.fandom.com//wiki/Ailment_Talisman
# https://eldenring.fandom.com//wiki/Ainsel_River
# https://eldenring.fandom.com//wiki/Ainsel_River_Main
# https://eldenring.fandom.com//wiki/Ainsel_River_Well
# https://eldenring.fandom.com//wiki/Alabaster_Lord
# https://eldenring.fandom.com//wiki/Alabaster_Lord%27s_Pull
# https://eldenring.fandom.com//wiki/Alabaster_Lord%27s_Sword
# https://eldenring.fandom.com//wiki/Alberich
# https://eldenring.fandom.com//wiki/Alberich%27s_Bracers
# https://eldenring.fandom.com//wiki/Alberich%27s_Pointed_Hat
# https://eldenring.fandom.com//wiki/Alberich%27s_Pointed_Hat_(Altered)
# https://eldenring.fandom.com//wiki/Alberich%27s_Robe
# https://eldenring.fandom.com//wiki/Alberich%27s_Robe_(Altered)
# https://eldenring.fandom.com//wiki/Alberich%27s_Trousers
# https://eldenring.fandom.com//wiki/Albinauric
# https://eldenring.fandom.com//wiki/Albinauric_Archer
# https://eldenring.fandom.com//wiki/Albinauric_Ashes
# https://eldenring.fandom.com//wiki/Albinauric_Bloodclot
# https://eldenring.fandom.com//wiki/Albinauric_Bow
# https://eldenring.fandom.com//wiki/Albinauric_Mask
# https://eldenring.fandom.com//wiki/Albinauric_Pot
# https://eldenring.fandom.com//wiki/Albinauric_Rise
# https://eldenring.fandom.com//wiki/Albinauric_Shield
# https://eldenring.fandom.com//wiki/Albinauric_Staff
# https://eldenring.fandom.com//wiki/Albinaurics
# https://eldenring.fandom.com//wiki/Albus
# https://eldenring.fandom.com//wiki/Albus_the_Albinauric
# https://eldenring.fandom.com//wiki/Alecto
# https://eldenring.fandom.com//wiki/Alecto,_Black_Knife_Ringleader
# https://eldenring.fandom.com//wiki/Alexander
# https://eldenring.fandom.com//wiki/Alexander%27s_Innards
# https://eldenring.fandom.com//wiki/Alexander,_Warrior_Jar
# https://eldenring.fandom.com//wiki/Alivestone
# https://eldenring.fandom.com//wiki/All-Knowing_Armor
# https://eldenring.fandom.com//wiki/All-Knowing_Armor_(Altered)
# https://eldenring.fandom.com//wiki/All-Knowing_Gauntlets
# https://eldenring.fandom.com//wiki/All-Knowing_Greaves
# https://eldenring.fandom.com//wiki/All-Knowing_Helm
# https://eldenring.fandom.com//wiki/Alluring_Pot
# https://eldenring.fandom.com//wiki/Altus
# https://eldenring.fandom.com//wiki/Altus_Bloom
# https://eldenring.fandom.com//wiki/Altus_Plateau
# https://eldenring.fandom.com//wiki/Altus_Tunnel
# https://eldenring.fandom.com//wiki/Amber_Draught
# https://eldenring.fandom.com//wiki/Amber_Starlight
# https://eldenring.fandom.com//wiki/Amber_draught
# https://eldenring.fandom.com//wiki/Ambush_Shard
# https://eldenring.fandom.com//wiki/Ammunition
# https://eldenring.fandom.com//wiki/Amon
# https://eldenring.fandom.com//wiki/Amy,_Third_Sister
# https://eldenring.fandom.com//wiki/Anastasia
# https://eldenring.fandom.com//wiki/Anastasia,_Tarnished-Eater
# https://eldenring.fandom.com//wiki/Ancestor_Spirit
# https://eldenring.fandom.com//wiki/Ancestor_Spirit_(Achievement/Trophy)
# https://eldenring.fandom.com//wiki/Ancestral_Follower
# https://eldenring.fandom.com//wiki/Ancestral_Follower_Ashes
# https://eldenring.fandom.com//wiki/Ancestral_Follower_Warrior
# https://eldenring.fandom.com//wiki/Ancestral_Follower_Warrior_Phantom
# https://eldenring.fandom.com//wiki/Ancestral_Followers
# https://eldenring.fandom.com//wiki/Ancestral_Infant%27s_Head
# https://eldenring.fandom.com//wiki/Ancestral_Spirit%27s_Horn
# https://eldenring.fandom.com//wiki/Ancestral_follower_warrior
# https://eldenring.fandom.com//wiki/Ancestral_followers
# https://eldenring.fandom.com//wiki/Ancient_Death_Rancor
# https://eldenring.fandom.com//wiki/Ancient_Dragon
# https://eldenring.fandom.com//wiki/Ancient_Dragon%27s_Blessing
# https://eldenring.fandom.com//wiki/Ancient_Dragon-Man
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Apostle%27s_Cookbook_1
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Apostle%27s_Cookbook_2
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Apostle%27s_Cookbook_3
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Apostle%27s_Cookbook_4
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Cult
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Florissax
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Fortissax
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Knight_Kristoff
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Knight_Kristoff_Ashes
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Lansseax
# https://eldenring.fandom.com//wiki/Ancient_Dragon_Prayerbook
# https://eldenring.fandom.com//wiki/Ancient_Dragon_
# https://eldenring.fandom.com//wiki/Aristocrat_Boots
# https://eldenring.fandom.com//wiki/Aristocrat_Coat
# https://eldenring.fandom.com//wiki/Aristocrat_Garb
# https://eldenring.fandom.com//wiki/Aristocrat_Garb_(Altered)
# https://eldenring.fandom.com//wiki/Aristocrat_Hat
# https://eldenring.fandom.com//wiki/Aristocrat_Headband
# https://eldenring.fandom.com//wiki/Armaments
# https://eldenring.fandom.com//wiki/Armaments/DPL
# https://eldenring.fandom.com//wiki/Armor
# https://eldenring.fandom.com//wiki/Armor/DPL
# https://eldenring.fandom.com//wiki/Armor_Sets
# https://eldenring.fandom.com//wiki/Armor_of_Solitude
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_1
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_2
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_3
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_4
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_5
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_6
# https://eldenring.fandom.com//wiki/Armorer%27s_Cookbook_7
# https://eldenring.fandom.com//wiki/Arms
# https://eldenring.fandom.com//wiki/Arrow
# https://eldenring.fandom.com//wiki/Arrow%27s_Reach_Talisman
# https://eldenring.fandom.com//wiki/Arrow%27s_Sting_Talisman
# https://eldenring.fandom.com//wiki/Arrows
# https://eldenring.fandom.com//wiki/Arrows/Bolts
# https://eldenring.fandom.com//wiki/Arrows/Bolts_(Shadow_of_the_Erdtree)
# https://eldenring.fandom.com//wiki/Arsenal_Charm
# https://eldenring.fandom.com//wiki/Arsenal_Charm_%2B1
# https://eldenring.fandom.com//wiki/Arsenal_Charms
# https://eldenring.fandom.com//wiki/Arteria_Leaf
# https://eldenring.fandom.com//wiki/Artist%27s_Shack
# https://eldenring.fandom.com//wiki/Artist%27s_Shack_(Limgrave)
# https://eldenring.fandom.com//wiki/Artist%27s_Shack_(Liurnia)
# https://eldenring.fandom.com//wiki/AsR_(Antspur_Rapier)
# https://eldenring.fandom.com//wiki/As_You_Wish
# https://eldenring.fandom.com//wiki/Aseo
# https://eldenring.fandom.com//wiki/Ash-of-War_Scarab
# https://eldenring.fandom.com//wiki/Ash_of_War
# https://eldenring.fandom.com//wiki/Ash_of_War:_Aspects_of_the_Crucible:_Wings
# https://eldenring.fandom.com//wiki/Ash_of_War:_Assassin%27s_Gambit
# https://eldenring.fandom.com//wiki/Ash_of_War:_Barbaric_Roar
# https://eldenring.fandom.com//wiki/Ash_of_War:_Barrage
# https://eldenring.fandom.com//wiki/Ash_of_War:_Barricade_Shield
# https://eldenring.fandom.com//wiki/Ash_of_War:_Beast%27s_Roar
# https://eldenring.fandom.com//wiki/Ash_of_War:_Black_Flame_Tornado
# https://eldenring.fandom.com//wiki/Ash_of_War:_Blind_Spot
# https://eldenring.fandom.com//wiki/Ash_of_War:_Blood_Blade
# https://eldenring.fandom.com//wiki/Ash_of_War:_Blood_Tax
# https://eldenring.fandom.com//wiki/Ash_of_War:_Bloodhound%27s_Step
# https://eldenring.fandom.com//wiki/Ash_of_War:_Bloody_Slash
# https://eldenring.fandom.com//wiki/Ash_of_War:_Braggart%27s_Roar
# https://eldenring.fandom.com//wiki/Ash_of_War:_Carian_Glintsword
# https://eldenring.fandom.com//wiki/Ash_of_War:_Carian_Grandeur
# https://eldenring.fandom.com//wiki/Ash_of_War:_Carian_Greatsword
# https://eldenring.fandom.com//wiki/Ash_of_War:_Carian_Retaliation
# https://eldenring.fandom.com//wiki/Ash_of_War:_Charge_Forth
# https://eldenring.fandom.com//wiki/Ash_of_War:_Chilling_Mist
# https://eldenring.fandom.com//wiki/Ash_of_War:_Cragblade
# https://eldenring.fandom.com//wiki/Ash_of_War:_Determination
# https://eldenring.fandom.com//wiki/Ash_of_War:_Double_Slash
# https://eldenring.fandom.com//wiki/Ash_of_War:_Earthshaker
# https://eldenring.fandom.com//wiki/Ash_of_War:_Enchanted_Shot
# https://eldenring.fandom.com//wiki/Ash_of_War:_Endure
# https://eldenring.fandom.com//wiki/Ash_of_War:_Eruption
# https://eldenring.fandom.com//wiki/Ash_of_War:_Flame_of_the_Redmanes
# https://eldenring.fandom.com//wiki/Ash_of_War:_Flaming_Strike
# https://eldenring.fandom.com//wiki/Ash_of_War:_Giant_Hunt
# https://eldenring.fandom.com//wiki/Ash_of_War:_Glintblade_Phalanx
# https://eldenring.fandom.com//wiki/Ash_of_War:_Glintstone_Pebble
# https://eldenring.fandom.com//wiki/Ash_of_War:_Glintsword_Arch
# https://eldenring.fandom.com//wiki/Ash_of_War:_Golden_Land
# https://eldenring.fandom.com//wiki/Ash_of_War:_Golden_Parry
# https://eldenring.fandom.com//wiki/Ash_of_War:_Golden_Slam
# https://eldenring.fandom.com//wiki/Ash_of_War:_Golden_Vow
# https://eldenring.fandom.com//wiki/Ash_of_War:_Gravitas
# https://eldenring.fandom.com//wiki/Ash_of_War:_Ground_Slam
# https://eldenring.fandom.com//wiki/Ash_of_War:_Hoarah_Loux%27s_Earthshaker
# https://eldenring.fandom.com//wiki/Ash_of_War:_Hoarfrost_Stomp
# https://eldenring.fandom.com//wiki/Ash_of_War:_Holy_Ground
# https://eldenring.fandom.com//wiki/Ash_of_War:_Ice_Spear
# https://eldenring.fandom.com//wiki/Ash_of_War:_Impaling_Thrust
# https://eldenring.fandom.com//wiki/Ash_of_War:_Kick
# https://eldenring.fandom.com//wiki/Ash_of_War:_Lifesteal_Fist
# https://eldenring.fandom.com//wiki/Ash_of_War:_Lightning_Ram
# https://eldenring.fandom.com//wiki/Ash_of_War:_Lightning_Slash

# %%
import json

with open('eldenring.json', 'w') as json_file:
    json.dump(data_er, json_file)

print("JSON file has been saved successfully.")
# Out:
# JSON file has been saved successfully.

# %%
with open('eldenring.json', 'r') as json_file:
    data_loaded = json.load(json_file)

print("Data loaded from JSON file:")
type(data_loaded)
# Out:
# Data loaded from JSON file:
# list
